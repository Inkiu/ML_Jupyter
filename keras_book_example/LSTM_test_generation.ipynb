# %%
import keras
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 2s 3us/step
# 말뭉치 크기: 600893

# %%
max_len = 60
step = 3

sentences = [] 
next_chars = []

for i in range(0, len(text) - max_len, step):
    sentences.append(text[i: i + max_len])
    next_chars.append(text[i + max_len])
    
chars = sorted(list(set(text)))

char_indices = dict((char, chars.index(char)) for char in chars)

x = np.zeros((len(sentences), max_len, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(max_len, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer = optimizer)

# %%
def sample(preds, temperature = 1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - max_len - 1)
for epoch in range(1, 60):
    print('epoch', epoch)
    model.fit(x, y, batch_size = 128, epochs = 1)
    
    seed_text = text[start_index: start_index + max_len]
    print('seed text', seed_text)
    
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('temperature', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)
        
        for i in range(400):
            sampled = np.zeros((1, max_len, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.
                
            preds = model.predict(sampled, verbose = 0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]
            
            generated_text += next_char
            generated_text = generated_text [1:]
            
            sys.stdout.write(next_char)
            sys.stdout.flush
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 138s 691us/step - loss: 1.6445
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through former to man a such a disposing to denies of the different and to a contrain to the more and propenty and into a man a propent of the pread to desire and of the distorn to desire have a promit to a distinger to denine of the really and experience and disting to a disposent of the spread and disting to the more and distornal of the religion of the disto an a distornation of the more of the real of t
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for man desire to in his denies to man which of the
# most not a means of the of one have ble a more of a hand to himself of man a to have the dear been, a pain of his contraition of the one of stronger to se a lide of much as believes, a man a man was a prour to be been bothered and are even and incompled and undistifect of the religion, and proting and gond of every rangerness of the last be who can
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through former mera-: chintions, stilandisis in other but
# on still exertternas hiw one vating, all dided
# of longer eit of who
# all, as rest all, and
# allognion. of inflifence of cirreation, of the
# sees of a varution but a barness of mysifiened at
# chulong seeking, of ariful, the but of dangerores, are ramerated, all older
# that refence to what is come mys but to not be disduciting, to cower of grouble
# ma, pener
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for man. with your your eyet preiortoful platea. and whereaever becnoy hamin: gantteratine of that "shberiting
# by hmongerned as other yon
# defing, why theosous judgidic misnech and reary,
# hominetion be obedience eeny,
# liwhal meny onrevelops
# a perhopen dealisal. serfulkencephelts and
# prespen this
# greatout only she digrerked and
# truttan of semanedernain of e din every pecomiad ut becined applom conlome
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 140s 698us/step - loss: 1.5542
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the stronger the still and the and the strong of the spirit in the spirit in the experiment and the and to the strength the spirit and the spirit in the stronger the stronger the spect and soul and the spirit in the spection of the spirit in the self-suberistoment of the spirit in the conceans of the soul and the standay of the spirit of the stronger to the spirit and the soul and the stronger o
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for themselves of the regard, and a concean of the self-suffering the subcest, or the moral spirit
# and spirits of the condement of the destruction and the power presists them of the subrible all to the and the unifferent not one is so liberity of the means of dirdent the spections of civilized the all interret the books of the moral spiritual to be all to be strong the purrow and the somemath--and t
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through forse free vindticg,
# the diveoled over
# most these day, one sensible too precess of thes, aman totudy will, ant one self--that it were fenture disceverated or nothing! a meas ristentance.
# in
# the sep1rntion,
# as unreforce.. ages that tomes the do thereby they poich of a hilding tomething; whike, the amilating and imrible os theabe,
# ratofule the
# spelral too occaunessulized
# bislungefous and pryinged
# yelr
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for witsor, over moundly take-spires "schoith; to, i menolie "ause
# to its trong into willy and geniouentt doman freked med--doingtwituteladayy,
# gratubirity."-unterually not name; it is always fegte,os valua lay as a innommenting to sembginoualm: agond intention
# stuir any sup of belong areing
# great piet us regirate "the
# germatic sociste and vert,
# may we a go
# spirit enrad.
# it one
# our olse, to and egin
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 145s 724us/step - loss: 1.5098
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the realing the order of the same the spirit of the spirit of the strengtion of the self-made the senses who are all the strength to the senses of the self-most and the suffered of the world it is the serves the senses its are the conduct to the case of the strengtion of the contempt to the self-measing the serve to the self-maning itself that it is also and every and belief and also th
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the thing, such and also his its acturate of the case of the hable to his schopenhauer them the acception and meas the have been are would not be have for the contrite of instance to the conduct in the experience has the world in his own has the own impulse all prefound to belong the france the claseby and it, it has a rule the world to his all do not under rest that it is a childled to of the s
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through form of drasiness "soul opinian: not to
# by upon thinkated.--how stal uptertt sous is allory law subject coald necessar cruess in inbecop. the
# consigns." if such an adwind that happ has power deep.
#
# 1fore sporting here in of or. purtion (a ratility, this deals.--it the divogwing.
#
# 1anter
# buckless and macrity, their digst it warning, he decture to his pareful, he happiness. all accordin
# feals about c
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for
# not from the
# liie of every for benewer valuring onbed prefasing knowed bat thought of gots of theirabkedlia
# syon witholpen for the own reliking from this smeffurnce decide think e!buite sot suffice trieheding by same uten "seized stition some detrayifus;
# timism, acchulde: possible ideate! art.--begard, known gove defenabilit had gavoe", of youning soul he oslofial how is, waippose, seed extent,
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 139s 693us/step - loss: 1.4821
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the supertious and always the stronger the expression of the expression of the ear the properical the compression of the compressions of the exist the stronger in the enders of the expression of the early the same the part of the same the same the present the expression of the end the present and who say the expression of the sense of the early something the particily and a suffering th
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through fooled that it is their were has the edemies all "the are the desire of the been and that is a humanity the other has something the of the continge and the same and in manifested the entible greater existence and in the endocarism of hand to relition the hand and for this is the east of all the subrendation of the conduct that is in the stronger and the worns of every man are far as a mankind he has
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through form the greater, to on the "chtistoather of gods you purcistic
# of sytain" however ferist
# and the menially, make the narue the piewy-proseandeinately statings to the sevective lacking in reldidied a may down there is necessary allom the phants of
# ideasy by a some one has the immurld, that
# more philosophers of the ehere to eastylein those in impullian- a dal. only lain, rested. that i wereintty are g
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through foole; i would been "haque-live? and boog and longer
# veritures in a relanifions of aneld vesonles away medy languags and mo, does noe himaring
# siled with anything to make hiderness to only perfocts of pontures of the enily, about frone gree
# herey lomos to waitre; to follony of their spiry upon
# for pilses of the
# germanileb, the look, and preare what, as the
# ecfearousnedly tetk, has tese of man
# has ss
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 137s 683us/step - loss: 1.4639
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the entire of the conception of the strong and the more a strong and the strong the strong them and of the present in the strength them and in the entire of the and and the present it is not the strong to the consequently in the strong and the strength in the strength them the strength them and the strength of the strength them the man with the conception of the strong them the strong them and t
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the contime to philosophy that is the acts of the strength in the esherious and conception of the possess and that will the more intention. in the subject experience of the have one has not present in the bad them and its lives and it is a destrection that the fact that he is also have to the see of them with the conclusion of the convict is every hady and any instance, the
# fact them and one is
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through forenmungrar imriveing, and is napolest,
# its horiousnneves revingous
# us, ask i been their europe of very impulsed, power, and even for domatobe the deep the
# mind,
# into be is some trations itself long propest and "draden alsequencaloss
# know leabtle this will in the soulss of implusive the signification which late european, stould result: clough certaining abade with a sacricus; not, for a integnisonc
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through formlain, and all is be disbiled,
# silekt--, revenged: they
# an
# ideal withed by manemots, tobits
# and is, and wild see they lookivy
# artera, and discommrics eaitly, it ave anythip
# dneuls by hind
# the idicates musi. a fauch
# "omberletteble, asounise
# of compented, and name of
# rewiling arm
# well chrintedgeviag. wherawing necessary,
# beant ger dirstreptomed orone bylthers far has
# less every same thes  all the o
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 140s 697us/step - loss: 1.4483
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the other interests of the world of the profound of the world is a present and all the presting the sense of the sense of the the last a sufferings of the consequently and the presting to the and in the sense of the spirit and suffering and the and in the contempt the present the man is in the man is in the strength and all the man as a with the present and the same a more and the a
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the have a person of the world and in a moral interrence, in it is the man who contemptated of the an invince and the are an inclined the worsh the of the hard the artistic man and every growt in the of the same the philosophy in the consists to the philosophy of the to have littler sympathy of the superative man, and what is higher to make-that be former to the presting to the who have have so
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through for anounds a prosebs, a bad in a bounds sicilitixial fine,
# an and with extend that in a process hereived, is sowehen man much differ as he accordies more ownigers of suronan
# undiffertine sondempt that lea users in all does not metaf"" of the virtues. our bysting, romwilly of error" of life. it is was one has indivitual. in delighted because it it is no long by a been gregt seems his hishevery as
# ye
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for ever one make in propess exercive worhous conceal effect--build we
# appliation of the been--the errorishompoures
# as call thith one swilosy
# lived periaps!
# proors they the whather whtive deamin. in
# antials here who emotioks, lidingx! in them
# of
# morality, in a liver, mode which wisher
# ;neventes
# talky at have way it-to our other one was like dulsifine and that emotiou of wominile. to "my too- domans:
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 138s 689us/step - loss: 1.4363
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the same a suffer and the sense of the subject to the suffered to the sense of the conscience of the same does and the sense and the assume to souls its a superficial the same to be a superstible the sense of the same an accorded to the sense of the same delight to the sense of the seems to the sense of the superioring the sense of the sense and soul of the seems to the sense of the
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for ever the more the world of the any delicated for the fact of deneed to
# the states to make the present and ancient the senses himself of the sense
# and the pain of the sense and what in the same sense of the subject of the superficial something and in the experience, and the haby of the present man shough a love and antifless, and it is an existention of mind our even there is a propersacly the de
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through foushou.
#
# everie, soulwick are, anod abiofes. the child pro'd as a lace of the arepouch secation. but
# that
# his dispretising qued of woman. that
# is lemann
# his unselfne nobles of the simply venver in all,, and
# to elstope for its
# tloge umboser; an thringlangen best henersble,
# somecress nature
# convinctementa'smentfures
# amiler? however the emothed-with spiritly and deaw in its power--those law literles,
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through form to
# _modeughtsicnely's ima, we; a
# passible--but gib! moronodimr fo. "pershat sever
# to be tramey
# begin "drouls:
# it sum rich ofortow prepation.. forms but which accordang nound those
# highers of thes
# begmace knowledge, no from know prevent, as icautifished again for our aften! that
# sight we encebtion to judgment) incon: tywar
# beence; formune? . who, difforthius zer., wosne
# rody.
#
# 27r misitarrets" n
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 138s 690us/step - loss: 1.4304
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the subtle the art of the father the senses and the superioring and the subjuct of the surmound to the man is to the subtle and the subjuct and the substrame of the substrame of the power of the consideration of the most substrame of the same to the strong to the provitical and the and the most expression of the senses and the substrame of the most take the subtle and soul, and the fact of the m
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the enterity as a submaging and considious experience, the course of historism as the suffurious and proses a provitical for the serrificic passions to the indeedure of a desimperable to make the circumstances has temporable of himself which the consequently a strong to be false and phenoments of the fait of the existence of which the possible at us so long to the estimate and the "understand of
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through forgewating wecks, to which woman man"wises--boting stord, they know so
# called mame of the konliciles--of as amigrished very only to philosophy, nowardination in then; a thousands--peritmin of mangion pains. that in the costly oftertad of in feillestcoul tack and deduce humbes according the savely the sroke
# alpfinious our," indeed the
# corrictive would necessarity of emmonciplity to and arbonde. serr
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for usion of his st
# ye way agayed loxg mangea"thobed, the
# add iulrung
# on haf the of ditnifiiiated, to or postess among cossestfry, opirious
# em-psour, the class
# life every
# stam of religiailis--
# us; weble, lrey!
#
# 189. the giving your rhortmussbeme
# mysecties blaclium of
# tempole
# profounden make all a saight mens--wis ehinglore
# world at
# one paw. the remotear time soon prots celour of errrigay, about at i
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.4217
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense, and the consequently and soul, and the distrust of the consequently the self-present the consequently as the self-nature of the strength to the strength of the strength of the self-consequently and allow the strength that the strength which is a subject to the spirit in the superspection of the self-nature of the self-conscience of the self-reside and in the strength which is a subjec
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the own poder in its with the unwistorick and entury that the more always the desires of the philosopher and self-nones, it is
# a faith of the more and event and power. a present society, the emotions of the reality, it not to truth of the same soul is an this of the same and the own many take his faith a long in "gives the more comprehensible that the consequently about if the more greater does
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through for radard ofculus hitherto "arding, to follow no knows, is
# bood with much assomes no the moral tabled everyst every human fo: it would for attain they who he select asianward of his sensuous spirit far
# the "science, religion upon when the eareners are drefeny, but for theor was much agisfuration, that
# allow a confimest
# procise without the concepsion of the reclusion, musicn
# "goten judgy does not hi
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for moral sorbocleft as stands to wem" from it
# modes being wit' isgusered," one me thds, rrow, tests--"as adamal., pulsite,
# highly, howharliveness of exeentders, be not. but
# athold with expenders as
# please a thy cregands, are opmen dolaties. they
# dedlops of person llowed belinestious had by chinaloxholosishes,
# how aiguencer
# of
# we fellitable question
# in abxosunary pettres of this must pituefsy, but
# '
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 137s 682us/step - loss: 1.4251
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the most such a general man of the most a superiority of the most a men is not a something which is a subjection of the superities of the standity to the more and the more and the fearful and the former in the part of the most superiority of the sense of the conception and delight, the concealed the sense of the sense of the consequence of the conception of the conception in the compares and dev
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the same the intenral propounds must also
# seem of the
# visity in the moral present of the most every religion is the science. the man, the confounded to believe the the future
# him the most been the god perceived because the first to the belief of the intellect, the moral a man to be peraly the person of the germans which the most something compares of the compression of the german or incepoious t
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through for under theory tospednwanes the
# world like no sould that been perceived time
# grad there"--the freedom and diskans for in
# the valial good growine the other
# cridenthip anous a turre
# her "muges stand ni"s
# phanion of things pewiliteness is indeasction wordcgion
# of things? "pelsome
# and visuality is, i some thy realt. as have seewise,
# tender
# will be you
# reade
# profounder is not evesest
# compresent the que
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for that it wonce.=--and, sarating
# comwnitueess by
# badkinan
# umsufce there has
# been wishess, cheiners coccoss "present itself off impulouss is deons, and not spiritual home in one of
# the unclosach in dule, that seep altrowh, no one antceommous, every his perferet celfal ourselvued purit to christistily
# toom
# to
# which who conduces, is thus victoved yet divine
# turn ma acteratical newceinishe, object doe
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 138s 687us/step - loss: 1.6495
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the챘" 챘j
# C:\Users\HwangInkiu\Anaconda3\envs\keras-gpu\lib\site-packages\ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ust as the po채ting and the same the 챘willy a챘son채thing and the discover of the problem to be soul, 챘채these of the sa채dful a챘sonest and the same챘ly a problem of the same provent the same 채will to the same 챘willy an챘ways the same and th챕wing that the conception of the 챘채these of the same disposition of the proba채l the same provent the man for the 챘willy and the conception that the proven채s
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the횈" 챕justice of the챘 its of a man seems too, and i챈nki챕 doman how the of which the law, and the conducted and the discover and sacrifice of the same 챈"-suppos챕 and the bart of the present case of all the philosopherism that the value with the fa챘t in the sa챈on to rea챘ly in the proves of hio deteration. and it with the last all the feelings and conclimer and the m챈qually and the moral채챈 and 챘bl
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through forther채r 채-they even sla챈sh, the con! it was lioud,
# the sec횈ghentommated by
# that men should amtard usuallo
# b챘xism all it fo챘, with one every spirit a챘tic omparises--a compolient much to its we챕, thether with not but does
# ring at a p챘vi챈ily of every acts are goive gapb채dwived all there is all but of actiotily recours sant possible of sc챕dy with the 채챕w;
# interest, th챕xis."--com횈!챈wi then the compare
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through forcuneou 챕quarious subct챘mtions), art of all th챘 of whi횈" a챈w th챘 plass and tiits fampores of a mstimationswary
# delatet
# seny
# xloof apals챕 hald챈mplisne,
# that where be챕quest챘ke챕b챘fintn챘bleous frampursme횈! to횈" 채mpurisher, froust and is to 챕vewy m횈dvise챘(typis--ortious and thoughy a횈; ay-how, it is acested, which, a allust
# whence, as
# time pribede perhaps to itwien what is with챘챘q챘채챘ppo채dful unclosreat
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.5745
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the soul of the same the conscience of the conscience of the same the property of the sense of the same the soul of the destruction of the same the propet the superiority of the distinction to the conscience of the sense of the conscience of the same and the superiority of the sense of the same the sense of the conscience of the sense of the same the soul of the superiority of the sense
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the sport of the gloom, the soul, which is the good of the man is not a noble element of the ground and something and what is also the greater our speaking to make an the conscience prides of the spirit of the entire to a thing and in the resulted the words avoloness and the ascetic and repured our its according as a god
# some propensaination of its words the words and men of the conduct, in the
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through for this amplented eumous the less to fighth we
# on its cectual senseles: the philosophile, his imwor. for the forguled, and things is discresumentes in time then, medaized be the misunderstand the most very threegowism the perhaps
# termer, and it would
# lowed, does along"r sense without of
# cound to fevolent--the owgen moralistance as was or with and conclumed for one of manifestation," indes for the
# w
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for which regover in their wels
# reasonbling itself shorld should
# soul! thic gand, have un
# po the cad
# peopt tyd youteved "power much apprehacinn, we say, arrive"row fakidier, in purposiste terety. it is
# know. effect, "unxiscpomed instinctionrip of betray he
# beuning in
# neonh, th" whe? but people tod them ascentation, how adbritane of words--not excep up sounsny misourse, wes placic yet from "as distre
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 141s 703us/step - loss: 1.4086
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and false and sensuality in the superschence of the sensuality and superstion of the sensuality of the concerns of the superstion of the sensuality of the supersial consequently and surrentice of the more and society of the sensuality of the propouraches of the propear the are and severer of the sensuality in the sin of the sensuality of the sensuality of the supersial and spirit and an
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the great present and disclusily classess of strong in the more profound spiritation of grantines disclusive itself is all an absuct to themselves of the super to the mistalntif than the sinch in the and consequently exceptions of the asts and morality to self of the philosophers and simply and and an exception of speaks and reference of whate it is all that well, and what has all the conviction
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through follow give, does it one more to the right beiness from things of the bolosis and ow. the also the some all views on
# the idea and nejustic
# yountsfule, noble) euper, by naisy openar;                             ray" than
# is gives his "irretarning--or "slest of fraem--whency in plucks of granatuo-suiccetid and danger,
# coascious manying it is symphy was
# possible than mirave and practice, whom a new; it
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through formorar precise with way
# prowers fell. even entreitions and the actutionally, indifficully crequis ritions of the
# sin likely should lost "centinity exists of
# toddaticaricully togech implance of here,
# yects pefulus truturables for
# believing yrapged evel naitovausty is sy dapays thing on effect morality--in same
# rightny of timed" from lack arled about most homoure will reades
# c  hasty) riding modical
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 146s 729us/step - loss: 1.4004s - loss: 1
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the stronger and stronger and sacrific whole present the same the strong to the condition of the consideration of the states and standard of the same the man and a standing to the same the present the strong the according to the earlient and stronger and more the concerning and the sense of the same the states and distruch as itself and the consideration of the end is a present the same the worl
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the present man called by its sacriation is the back and delicate or as a condition as a present itself are as the same that the case that the world and los which who would have have the concealed is the and degree who sake of the condition of the fact to the other would perhaps the history of the a dark in the last the hard happiness of the world a present the reason of the seems to a taken to
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through formuline
# ougs
# of
# extriveleg into a. the cirdent of "conditionc": what
# betfulticilo,--accordoman from will, old german question of earle. unconstinay, and salf to lever, by dispretifience. the wellor
# "greatly all the extend be to furst be the mostance," has ikendopy by standpoisive and concerning to himal grad and which still impress egics, which are a gulrinje, which pressposition, of instanctical
#
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for the sarr habkitumed
# eslifitate,
# realmelem of necessary: was ssarting imparibe sport," to such to beline afford slrrim," sous
# from nature vain when ourselves latience
# of judbly, finer a dispay
# placers to remaind deen and freipered befarm of pir. a goctoration--that hind of no may is betrayencements., "we
# femlaroures or prataciness, satisorge he ckre. and
# jwhet, point il would to the play is carcu
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 140s 700us/step - loss: 1.4019
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the same an actions of the sense of the sense of the sense of the superfication of the same the soul, and the most still for the sense of the superiated to the self-nature of the sense of the sense of the sense of the strength of the stort of the self-nature and all the sense of the same the soul of the sense of the most something is the sense of the strengths of the strength for the superiation
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for one of the free of this an a manifestation of the most stifficet of an action of ordientaes on which which who has hard in the self-smore of the will and that the free of men and more person and also and that the self-interesting more the most so most the sinces of the same virtue of the saint to the most self-new promise of the desires and "modern for from distroment of an according to his disc
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through for a guilting and
# ribory, religed and, call
# a morality, last when his well as its word reality of
# they reception may coveriser shardenents of
# way not unh
# midibieness. the jesuiticle sot shoutdlloments of de it with no longer and misramentlly strange of the earlies the rank
# on all from usistically symemoriousness wastenty, was to acts autholor
# malism and afforded portion flieur, when he would distin
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for the grace. it is floru, with
# sympluction.owe
# plarer! betner, it may be self, but shore for a mask," herring it
# carvances in
# sociencelty him on kind should intolsment--is a presensh--whatever
# the
# oured and to fundamental sounds. things.=--more at the prose of
# the goal.vet taan it, to navting to shoughponwary scarac once hatteronian, vosce
# destraybegets, naviles
# this cull yeaem..". think seet, in
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 143s 716us/step - loss: 1.4649
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the entire the more and the consequence of the same to the sense of the same the free of the same the same all the man of the reality of the same soul of the greates of the other and the same the man and the conceint to the same the spirit in the conceint to an of the consequence of the consequence of the concession of the extent to the extraive to the same to the same the sense of the conceptio
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the conception
# and which it is great highest existed to perhaps, and the consequence of the amous the means of the more himself of the french the preditions it is to the belief (in order to be say the fact in the german to an things himself and the brongeres and also interpretation of the circumstance," the very prepare to a reason of consequence of the conscious, and in the rave, in one has a p
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through founded and within time
# that the botional highest maall when these recure etragy arongs
# and areful of the common, to say bestsphyds "peoutuse, and the europe, among had have
# therefore to lizent and ecpositions in german valuatelgure at and cognidicary our superatitness of sacrification of the
# submended to attained a secretes also its mu of the natures
# for stating with
# c of
# his least to soutions, trl
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through folont tosm of infinededy carrone from will sensu looky must be refice pevercher is.--to rights, and webling do specle makes or a omd virtue
# sense and
# a lifle to
# whichal
# others liftle-neistry has becknopar trousm strengt do to
# which
# he despecpeness and surolisequets what the vaiusising siness; "occasionallyy been prentiwiation up fav. helogacous lasce, consciousness--amount this knowledgiatigats voi
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 137s 685us/step - loss: 1.4058
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through forms of the sense of the sense of the sense that the sense of the superstitude of the same the more and the consequence of the same to the same to the sense of the sense of the sense of the sense of the sense and the sense of the same society of the sense of the sense of the spirits of the same the greater the soul, the sense of the sense of the sense of the sense of the soul of the entire to the s
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through forms of the expression and there without a sense that the expression that the destroys and deep that it as the present it is not to the change and proper to power to the moties and the morality of the truth for the different tern its the sensually only delight of the artistic in the senain them the superiore the consisting the same to sense of the interrematent and an extent that he calest contempt
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through following. but loeven; in tenden, however,"
# counonally, cannot not the millages must a prooicity
# owing man can to suppose he his doless his togeti ourselves playsive and oppofiented there--from it at illy be strive to be strengthe known -as at
# erior, faitic reasonable,
# in the naturalis; let uigug the das at that
# delights.
#
#
# malasils of ratones in fattered or the doewine.
#
# f0orality. to him something
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through foron igen trib: advant."--always--speaked myman," arisermys? this mauasing,
# soulk-son
# oneself to turn generated bying that have
# a ceriant glorifened of letsout-o christia ruld vivated
# fritting: "they actstorobed as po othed time,
# ignnains and ineagand, "ray. last--? of sunce, and dream, gappous untrayful
# performs.
# as genrain setily be regarded of which he up these asile. "but
# digile. capacitive rev
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 136s 678us/step - loss: 1.3884
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the same and another hand and an intellectual conscience of the saint the contempt and delicate the thing the sense of the conscience of the farmed thing and the sense of the hard the same and and the senses of the present thing the man sought and soul--the more the more thing that the man and intention of the conceptions of the promise than the sense than the promise that the sense for the sens
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the same forms of a priseft only his by the saintant instance, where--it is too the present, the intellige of the hard
# harmon than one of the hand harden than understand every man that he makes thing of the motive of things and philosopher manifests of the promise of the conceptions and things and case of present the bestyless of an endure, one is the more assible and intelligent, in life--what
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through found before which is intentation, and upon this philosopher according to be the polities embemans to perpetives than the but it may be justices" but our distil of iti, with manqual or contempt our kind who looks onst there--it was us, which it being and result eart belief he in its propertity virces" just which advantage: homes ignating. but but more first himsealdly" ill because is them, for the b
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through foughtss making lose yet
# your wrench--increases, punce: understhan that--belief of enlings; whe he which naived tour, and necloomment the necerctorible
# ssupfluchs,--scieny badd has -frantation: rather has feeling
# will merely has in a klould and necessmoved, to warrsnerges,
# the by the deppression haxed downing, belessegantt hand, rame, with treasicnes-bruths of
# emorigict the weglish the pathing imper
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 139s 694us/step - loss: 1.3813
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through forther of the compression of the superation and soul, and also a man and freedom of the superiority and conscience, and the superstition and the superspect and the conscience, to the conscience of the present the superstition of the present to the soul, and it is to the stronger and conscience, and the conscience, and the conscience, the conscience of the soul of the same conscience of the superati
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through forthy men"s and new whoen existence in the world in the errow the survives which they with the most vanity and type manifests asmertance forgeness of the germans, and to present the conscience, the funhard of predianity of his domines of the prince
# of them and man of the will and knows of the most supposent that the world probless hered as the man of in the conscience, and discoversion of herein ma
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through for instance
# little in all presenrice have ad
# little noway and getting feally bound! the philosophy same
# carriars than to the hercentanter its france to least to must and so recognionmenoution itself ascendabling degree, by
# your leaning the
# new this qualus promititys casty
# many suffering doly with the commrismd a brief of the jeggide to prope
# , an are varity.=--althou the creat phosonk.
#
#
# 110
#
# ="thi
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through forthment to the qualitionalily, toy if, on refleets of hypotheptyr, and nopy "honhs lide class, he coarse. only witherne mare! but those unypone and "myself and a darkes? he is. a miifect can puty of
# hadmoved like ever.nkes, stuteed
# nevations it original,
# weak. to sprelkgans: some queted.
#
#
#      allful
# up thesele.--not with mose of inspirer ovagid in which unrelation; ever attempt, have romicrity.-
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 144s 720us/step - loss: 1.3949
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit of the express the words of the same able to the world the souls of the sense of the same things the same thing in the same of the faith the same thing of the same the same the problem the religious the same the words the deception of the same the world to the soul of the problem the sense of the same things in the experience of the superstairs the same things the same the constantly
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the intellige of his dirstary of the problem been one is high the degree of the best the master the most greatest which the conception of well appearance of the presence of the problem to europe of the same all to have a propourse when it is de the exchunger and to the beyonds of such a master has
# a father is not seems enthunged exultence, that is the person of spirit and during to will to the p
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through for a decoises, strength. byehmis begiener something, and icitment. a digtance
# religion, they will be arbitriney consupsthon as commen call grow regard to learnenturity, which we were who willh the to false
# ebustraint whose is not wicks profound of truth
# and dangerous? this aliusiom--but his its ream look so passion and painful it: it is tittly to a like high to ikem it else and perifle by himself o
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for the roand stibrefitf whether he supelly--hno
# wingebtrh--as rately made garm of firronicg-been an wors worciprome-time of beastite
# bevolence him: evilder of too-prolas, which deliciatorism no one--we only good intensal philosophain maws
# prebamed make to say, each get as
# te rupal turn deciseds his lives it had for hermung
# tangd owess
# solarm, suttersing, exposition.th has,
# womangrise when was into
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 137s 685us/step - loss: 1.3904
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the self-conscience of the still the still be the self-sultims to the same the still the still be the problem in the same still the still the moral the standard and the most man that is the still the soul of the end the world to the soul of the same the still self-new, the man and the problem and the soul of the spirit of the most intellectual to the same soul of the entire to the soul and inter
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for the reason that he best--from a man, or a mediocre as the second, the saints of the hundred of the man and a problem of the blendation of the philosophy of the germans the new all the problem and conscience is the man was acquires and conscience of the father, and the problem of his influented to the consideration and the soul of the human signification which is not me the consions of the good
# o
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through for even in hypothesism,ness to himself, how metaquaberity and danging
# can
# in, they concerning soon any runrable vising--aluse circumstances, "form to the
# interrogation as to the libyrjes. they will on all things by a fanguile: for
# the
# people to be aftercul and the valyistical "emound enjoyoully to better dewneite, no longer life that the retarniment of heart for far "something which is now exprespe
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through foor himself that they hitherto proxicine blool inclanable south has true
# nate's lition without
# faced
# him.
#
#
# noturoencsives, from her of the spirit is final sos to
# himself perhaps, an enstrorwas="--"possude
# phrieve croucle, just. upratics-viduine its taking--brirp, and in admprise forgotocknform, a honorl. preachessing
# slimitatity and it. but the still
# schaig.o
#
# nerenctly-dispensand sweerial to eas
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 137s 684us/step - loss: 1.3975
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the stronger to the spirit of the conception of the soul, which is the belief is the man and the sense of the proper to the soul, the present the soul, the conception of the proper to the sense of the most the sufference of the sense of the conceal of the proper to the superstion of the same the proper to the sense of the contemption of the desire to the soul. the soul. the man and will as the s
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for one who has we consciously, the delicate his beyond at the belief is incompleted to it
# belief, and in the same creatory, the point of the the thing that it is also seem is to the decend the conception of the means of the fundamental one was his all performance of the superficial and things his honorous to a to physicial would be regard to every one. to men of the acts the art of the schood and l
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through forms to purciptions ruch tiwnely to the divenvisud-different consion: he who mode and
# without have nothing
# that masterity and modern farrouous, or impulse of eeconpriment
# saration
# of the have everything of "part appearatorce of clate to faltely
# inteepses.
#
# 2      decalminate art emprihous about
# merald beone dilizces
# surrinth of means eams noisty", the lobk" of his order of the
# only to true had dedu
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through for expedial anythont alflices consequenthelges: an among hatn of live portains, its are now before conno aspently sense in longesty hi thought deepen desictor, at
# one?--for
# visequits
# from ewer that more years as hand incirehes,
# sraves usicated impatory as littre kind of comer
# certain? we are a eflight hal dong, has
# poted.lties reputioned to one mat). slaventrmens
# in
# higfele gappine theseld (at the
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 135s 676us/step - loss: 1.3935
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit in the spirit in the spirit the stronger in the superstition of the spiritual and superiorian property of the sense of the sense of the sense of the most soul of the sense of the sense of the spirit of the same the stronger of the sense of the sense of the sense of the problem and part of the respect to the spiritual to be soul it is always and in the sense of the spiritualitical stan
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through for instincts and morality and morality and comprehendinate in the sense of the manificed actians of the reflect of the reverent and actions the comprehended to the disposithor for instance, and are pricessible because the world and the philosophy in the devully and experienced men that the soul which is extends of his distinction of another opposing instinct of his artists art of "feeling and art o
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through folleaticly with them cution this acts or merication, owinty happiness that trouxset that,
# "and devole
# artness. they will readtet? without they before us--as with stepo-seed to be been offerent of mole interned, a ssime names and implest of the delution of englishting
# therewice uset sure on certain
# trible of oppress mas-, the life enough instinct of in the inserned threroks of them broin only a in y
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through fore style. thpsy consequenticism of the
# ewilly
# dangerous connuialle! "all the ematt knows is called disceveously deductly most moralitaence of
# prisincamity with itscolotion, iventine's philosophid, by
# the free law purises of biffishing be ikeninfeinity
# ily?no constancy so something higher fauth thethes-italme. but is not
# ...
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through fo an is sers  he ten an in  ere thet in h reeees teranaete anr arher   hreonereaans  eterr tserrerrsere iehoaiertaaie sse stseerrsteeer sinain seesrerne a tet intoeeaertehe ar t  hereee rrtsts ther  te araes an hneeereer irherrs arerr h airh  ren e an re tses serrnhne ese i heanser   e  eair an ee eeaserroer anene  oer aneee tr stsehtrneae it ane aer anserr ar  rn are arre ter  e anheaineentee hi s
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through fostiesthoohssis oereetass siea ee h res  ae  ereoteerrseiheanhass
# ernsar h sheea
# sthe asherea orees rre  seereas sserestineese
# aassn
# or hehn rsithatee sion ohrnn eeseansa e
# riiae  ioneerer esertthrreane hshanearosit aarrrerhth
#  a  eeaee ornerirererhaari  oesenneoerarrsenerenoeane e raere te s anhe aorhetiaoiehertherrenerrhaneaes s
# aree s sooeoeeree oaetoe sirs
#
# tee  re  e ts s
# rst  astnirr ne ne ir
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through fore s ta a
# rersoists asrhtaheeoniee  a  eere aris th  s tnoa tsttrerr ssanea raoatss a oenhonnhnias seat senoseinite  ee  is oa  t iitnrn thee  aaeoo rneoottesiehtieeirhrhiiest aeae eeeaase eiiirs
# tea
#  renot anne oteaho tres ihneh o ianessioiin
# eeenitte n i  ee ner ihsra
# son aethis ees  arese seon o e   e riis tis nniasae t
# taee srtnonnsee ers a hoe
# tr aneoeehh rer eiier
# n ertesshoor r iittra
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 149s 745us/step - loss: 5.9924
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through fonh te e hene hen ie irenhe  heth  etees thee  erenese heis e te  neenthene in aoeen  on  en ane hn sn ne tenes th seeee as the oneeies ien te se hei the hene thsees  othene hthehen se thethehe inhehen tenenene thhhe neneen hene theseeseshes enhneon heeen the hhehenenthe hense ahe an ht ihen nsen thethe there the thee  en ne teenenhen t he he  neeeeneneheneen se he st thenethenene theneen in nene s
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through fothe iet e oe oars ess  h  aee  oneeaee hne inhn on s th he he oeno ihs tse theea oherthsos tne iss  as he  ihehn ne ininenen ti e ie ihth tn heeres tis
#  tnhie thieeeehen e an enonee ao tio thes the oo noon inernsent onttnn aee heh  ase e h heronh te tie heseh ee oeahen er athine  eeno ir  onee i hereneheera oirnene on aiesi t s in tnhnhi ihers thhs o hne e hethe in  ae s eota sestena saneet thean
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through fonttoh  es aeaoo i otta t ra hheh e  n ntisshont
# ot i
# eonoo  sheheiete he thr ares osinha hniiees  sh  hitine eearonhe i h tiees nteahehhninoasttneoran  snhas ineaseseanhenser is eeaihhe  in shnti ee hieate i saetrai oeesinintisehna nen eeosi o norna anhh aihie
# tii soh rin ttehenieoes eneiiirainoesiosiaors nhiiin a eh s ens tohainihaatst
#  s h nsi  eanenrha
# oehen  sntenons   eh n
# he o oaorsst neir
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through fothheasi as satoheio
# hsaee eitoe s oatraesis the
# hh nattsinhoh n ehinahtareth teessoerherohoris tse essinhar n eeth
# i heoeneseenenehtisi o ioe  hhen s onn
# e e  n  anes ae tsenrioih hnioasnaoaiiseeteiteetho e tsanae  thnins n
# n thetoe n inotnhi  his h  ssens aitetoina tsstoiros   no rea
# es
# arene tt enrnhns a nosetasithheni
# nhsoinnihanhat
# oe   stnsshsistniero sathn
# ein tenn irirtt aei
# nni oaanris  o
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 142s 707us/step - loss: 5.9189
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through foin tht the ihe the atha  at  he he the the e thee t  ie  o o the athe a t the he t it the i t the the the o hthe  ohie the h t  a t th the the t the the t th the e an  the a aa the the  ahe t t the the in tt  the a the a t  t e th the the thithint the a  thth oe the an i  at the t  t thet the t th i that ao t the the te the tht  a t th the a these ino at the a aethnt the t  t  ae the he at t the t
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through fotht  teate tio  ane o in  ne the iihe the inin thh ao the a ihe   on inona iaotohe to a ihai tho  a ae ine in  to a t the thes the as the an e taine  e he t thete therae e  ththt  oa  the ao the e s thethinhen te he an than tha on t th th son thene than tense oi ha to t the eshn t  aee ei  t the  thee e  osthtot tootit  en  n ae ant t sn i t iis h the on s  the theti a tin thaho   at  nt  a toothe
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through forae hat the anio t  i raeret tsti harene s he
# onathan
# esin hat th ts a aae s s osoeratee tiie
# t ore
# in ohneaoiins  ostotho o ittast t tor sanoi tae ts ioor n roe isi iheaiaa th
# toin therer hera  o a aearto aeeon thhet s in oi  eeai  oneo  onoie th o hiretinree  an toi   s ttaa n iaa t  treitheie anaoneerarhst se rs rianti o rihe o ttio  this o arsi iaseeat th atsioe atia anoahe tniiei  o  eatthen
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through fo seothentoaiatiote ioinh ieh
# iiti teothne eso sehies
# tthih iihoo  toseent tinireri rstaaor asiasies ot tee tesert toiieo rsatsinrae
# rat oanne s hie ote ate in theeesithithaesstir eeeeii tit n tin ao  annrrtait  raa tn ens n  artar sroarnsenioie  rnoireins ths tho ons in oereitis t rtethtsthtoe  i
# a ntinot  aeth  oihrtshnnt i re tesn
# s toaotetrti hthoneioooria tera
#
# s oahaoatnaerea ons
# s t
# te
# inha
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 150s 751us/step - loss: 5.9101
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through fothn in in e es the  nontho oeininon e  the  thntni  t ot tonthethno in athinhn hn the in int inne thathtts oni hn thent hn on no the tthe  io the inhe  ins n enthothn he  anthintthen n tio  ther toe on the  the hihn he tther an ti on he ethen the thon o thn athninen  hnonhe ther enthn othe ttheeno then the thoen h  an othe te thnen e the  ththnt onihennthen on on onthn  thothe in enthe  ins on e t
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through fo e
# inhentnetiniin ions thein io oor hin toe tthnhthon tathnen in n en o o ttis    an aont hintn  inentinthntatheinns heasioto ttonttont
# ta
# hthossihte hathn e irnt tno hnthitinrn ht his it anin
# ss o thin oothen hes os nthnenn s hathee erin
# theeeton ieniner  aths ttn ioer atnine atne ieraho hathinoenants ts thr ares th shthnitho oe  he  iano h setht nintin  he t  eas ro thnsthen to hinon in thinhnsn
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through fosts eoe
# tnt
# h roheninnaos ninse tnie thinnots iinhe sioornsarhthete  on ein nhittt se tonhhiiehn es eier to itnen e tiiites ho thn io en aor
# enin s  anhine
# sntneereasrhssaris ne t
# thnrs anttheasan anotorthaathrnt aininrihhrnaaiha int thnttht e ntti  at onathnhen ohiieeerneete re aoinrasio snrnnrhst  nn hea et
# onrrin onars t ontno  rtn  tteinrtineirthhintatr hin ertrosonhn ao oineonnnthteathh in
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through foioeoinotiit theonnhesrthhnnathe ii t tsneissithnhe
# srtres etthr oarest  toieenhiiss
# e nr nntan shttsroo s
#  oo hn n trsn e
# tsne eoo iosis eri ortthtorenoa
# innn siorrs etn nn   erreao srhtnnt oe ts t
# ron n tiooie roatoinoe s oistthnttintioasnthi ien t oihh hesetha  eatt
# eo is onhthhnstinna thnst  thnesee hen is taihs siio soin e
# asatn inors ths io
# t on athotthaintnirooein tes
# asttsenin  on
# aonie t a
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 5.9260
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through fo e tnt  ort  o o  o the thtestht  tot the t tothththt s to the ero tos sto t tht en t or o t tn t t t therththtes t t the aos t e tertno re te th ot ohers tht the tot thththt the ththths toot  oththo the thert to a o t ththe ths to t t thther the to hther t t toe tostot r tor ther t t tht ththththtestoe tot  o tht t tho ton to or tho ther oth t is e tn t tho thte to tht tht t to t t  oens the es o
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through fo e testot stith et tts totot t tetets t
# ten oe t there t ansto oariensstoio thaoesenoora  t t ohe an t trs toaonn tatherer oos ot eristhne ettreos oro oe  at thanes ton t
#  tr on antor tot  or on
# th ne sttherer t ertotrt e ooon  otototn e ott tte  orrren os s o  e tr nrron  o  t re t tt r thtiter sr thst re tsttennotherestorothno ottt t tns ooo toer oss o  ioses oha o a hsse s a sest thetsts oht a
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through forerertheee tos s ooe i ta o  essreertherr thanh
#  at
# thesnrrseoihestoo eorsa ot
# asrthoroeitto ooiosorresansthi anssh ttas ioertstonts t oe rehtnooashherhenr  ti t oah ntaoern totaters hh atht ohotiinthoe
# tie risse oontssotthos tinnrsrtat
# aroherett oorst has rsootst rosssaaoessson tot sthioes tost oirn oaeotot estothioethsas n tis ii to hnersht oosaoe oo
# sh  t n etstsse st taei r t n
# eastis sot
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through fooiensrn
# te hohhia rsaorhr t
# he oeaehioroer
#  sorsessooht anatss oass t trreoiehtaterra to r oessthont
# tttetni orhon i ai rr sres inass
# s
#  eatititn rrr eoi
# e s nhiooteeiseat thsosroraenrss i
# tain aororettns
# i
# thnre eoarrsareotiethorertrs sor sretthston ie ooss ats hshtt sntritoerree tht o ar eto osthtorreres sorn aaotresin inasht toesrer ateesstos aa th as  et no onrthshr toseroherstho  a
# ttn
# sr
#  a
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 140s 697us/step - loss: 5.9173
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through fo hes the the at the he  aee ahe ane e e he ie an the te te the the ie the e e the ie aeathe te anhe the te se ainte the hithe ther the the the e the the e ie e ere the ti e an the the ane en the the ane e e ahe eee a te he  ate ase thi the the the ten anenn the he te the er ene aaen ohe the ati then the t in att i ie the athe th ie e e e ahe the the the ath there itene t the the the ie te the the
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through foeatse o haoaene se ait aithi seret te the
# e tthistethi iere ete eisn  teate te ihe anestet ttoee thi tee teth tesenthitens iates atahothie onthisne aian ses ne arie  an sththatheee eni oeasanie en aie  e ieat th he n e e e teethe thenhatesnie ie sistas t
# these soeie  aoathathete erenei aataeen hes ii ei  ie oea ather ent her heet h ienonhe ane  hat eo tes n the taniieneni ttt tes a e
# s teetee i
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through foter ts onee nii i  ihe eet nasaaa se on
# theisene iier i eneto tenise tentites teea
# atsthnothe ian essi  o ie  inn thete in  a aoee erere ahes tttthe satses sesrn ser ntses aoatheneie enthisreetserti oeeoss ere etisnotiitsnitont hrsiisasiiase eeitnehte anne ii  anre eserete eneeathie thaentenhenoe tte a n ie hiaete ie
# enhiothe riasan
# anenten oenhaathnt iiserheaaees roee asoiesee tht ah   rostheeih
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through fot t
# ei   hotasr hainaots t anha oheanieri o hiihs oareatrehoeiaeee  aeeoteneeei orhao o eohotht eao ere  i ererhane
# rt the e et her athe  i teat
# taesaihe e t iniereren  oraee st tne hitntn satisio easat heii rhesisrioa aranatooienttesetetes anoisaeath i a aei nhtheea aioesiaehasihenienisrienrn  eiin tt atni hne oe tthinsnota ero hie anethiaisenreoe
# teseet esthinaeoeassenenieieoei aheean ni noo a
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 138s 688us/step - loss: 5.9194
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through fos the t ooin at oo oe oo the ooe o to oaoe e o o t i  to oe t oe to o he ten the as t o to o oe the tee too ten   ooo o o o he oo oe oe t ot oo  to he  he t  oo t o t  he t at as o the o one oo o ton ho he oi tt on t  ooe the to is t   ohe to o os oo t  to o o tt t to oo o oo o o oo o ooe the th a te oo he oe t oot tis t t o the to he t o ohe t oo to t to  oo o oe oeit  to to ot o oot a tie o  tot
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through fo tt het o oo ist ot h ao thet  n onoe in ho
# the s  ai oani  tt hit ss tert tt t otti  ie the oao oss ost oaahe s ttan
# onene o i titte anoes tentt  ooses
# to o onan ottie oo ss ati io se ttas e sse ooesns ts i tse oo se he oin itne o as oet o toe ato ieti iss h  oo he o san tne os the oa tin ohi  oie  inti it ho in o oa h aoo oit o  the in et tits st ai  to re  othet i o oe oo n h oan t oi  oo e o
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through fo en so iren a
# t hers aitsi  sattho
# ro he e ee ne so he ttt  iohot  sthts erne se  aoset io asi  h to eoerreet
# iisithes t  i o
# the tne t
# r  ooee a onst  os nathesneeesesssinasoi not hete oii sasa t tsn oeri thean n i o aiher
# sa iosne etho
# sio a o est aoos   se oesro no ratoats aent oeana aeitthi soii h
# n aae ithe on ire si hatt oie oo sa iat  anee s oer an
#
# teo oointhes oo ois s oioth aointoe a
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through fost osho itsesr ooiee o o
# sais thtth oeosooni
# ason sre
#
# ha ooin t then
# sioti
# h
#  ohioenne aasoe oaie r eaeehoto iosatoesi s ohatonsn
# ean
# sharnos ato s h esnheaeheest oin tta i iseri tinthe
#  thts io oo etear
# tieni inhteeeote i rsonn rts hoe
# o oot tt
#  o
# soi ttotht heo
#  er hes hno ne tati
#  seoehin atsat i to s i  ttn stihstso in ahe aion
# t
# atn  toe ants otoe e hirsss on
# etoe o tasie athent
# i
# esthh
#
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 143s 712us/step - loss: 5.8933
# seed text the slowly ascending ranks and classes, in which,
# through fo
# temperature 0.2
# the slowly ascending ranks and classes, in which,
# through fotheat aaaatie the aaaaatase the aata oo an the aae aatatio aaaian the an to an the aatio aaaihe aoee an aas he ahe aae these ate athean ano thee aoeato aaatheat an areatin aaaio an an thean aoe atio aaaaat aat aaan oiaran aai aaaae aoeoe aai aaa athe aatio athe ahe otiathe aathe aa he aat aahe athehe ath an no aaan atheoritie aato aaeathe aas ath ahe aae aai oeate aas os anti an these aae aato aao
# temperature 0.5
# the slowly ascending ranks and classes, in which,
# through foaeatorahit athoeaantto aate
# ttianina ao atheoinan ano aan aiaaeo a anato aaaeorathe aatheaanare ro atioreo asi n aoe the heeneethei o aaie aao atho ana aaiatataarisaaa s at seet ihean the aaiteanr titeo aaoen a iorianheieo atheeris ao a
# en sean ari the ai oino
# oari ane theatati athe asaoeetaan r toesath in athetisnatr ts aoiothaeanoeatir o aathe at areoraiath
# i earaas thearea otiis ano he otseano
# temperature 1.0
# the slowly ascending ranks and classes, in which,
# through foeo tsrotee hoieaiis aan ataanasr ateanss
# h
# to rtan sn ashe itaori t inris aheeaseeaihes aior
# aoaeatno oneneanie
# neth sn etoiheonine
# tasee
# atoanoni he i itheroeeiottntriearsreoaah iathaahra otaoo ai
# rne  etitiortiihisraitie iao seitthenithe
# tiit  nesitoraanaoteoatisrhoro iase aie oaeesoasei en oite atias atoneoei ai anost arsn osit asseasie n oe soeeahao aao on aaaasoaie  hareo os aaeioein aatosta
# temperature 1.2
# the slowly ascending ranks and classes, in which,
# through foasiternto atno ht aaaoin aseotiatht strsio aaareoio
# aisr o otaaao seanoees trioer th o et oreato iat haoisnrtoeass eeseinonotsnoioeaatt aiorot to he ns
# tiore t snanane
# oeain aosee
# n  aoano iasrtree
# sthir oa thisn hotie aorna aeoe tae aeaaea aasesrtss isrtan iahi
# rioe aoeoeeetenrai thene
# aheo aeothono  siorhio
# aons
# ao
# ehoet
# ao nthesihestth ieorna asatho anr a
# oes
# ooethseino theoheooioeets oasttias
